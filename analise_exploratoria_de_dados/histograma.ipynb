# %% [markdown]
# *   Modelagem e Simulação - Análise Exploratória de Dados (Histograma e Gráfico de Frequências)
#
# *   Felipe Daniel Dias dos Santos - 11711ECP004
#
# *   Graduação em Engenharia de Computação - Faculdade de Engenharia Elétrica - Universidade Federal de Uberlândia

# %% [markdown]
# Histograma de um conjunto quantitativo de dados:

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

x = [21, 22, 23, 4, 5, 6, 77, 8, 9, 10, 31, 32, 33, 34, 35, 36, 37, 18, 49, 50, 100]

fig= plt.figure(figsize = (6,4))

num_bins = 10
n, bins, patches = plt.hist(x, num_bins, facecolor = 'blue', alpha = 0.5, density = True, edgecolor = 'black', linewidth = 1.2)
plt.xlabel("x", Fontsize = 15)
plt.ylabel("f(x)", Fontsize = 15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Gráfico de frequências de um conjunto qualitativo de dados:

# %%
import matplotlib.pyplot as plt 

Y = ["Bom", "Ruim", "Ótimo", "Regular", "Regular", "Ótimo", "Ótimo","Bom", "Ótimo", "Bom", "Ótimo"]

values = np.sort(np.unique(Y))
freq = np.zeros(len(values))
ind = 0

for i in values:
  
  counter = 0
  
  for j in range(0, len(Y)):
    
    if(Y[j] == i):
      
      counter += 1
    
  freq[ind] = counter
  ind += 1

print('Y:', Y)
print('Valores possíveis:', values)
print('Frequência dos valores:', freq)

fig = plt.figure(figsize = (6, 4))

y_pos = np.arange(len(values))
plt.xticks(y_pos, values)
plt.bar(y_pos, freq)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.xlabel("Valores", fontsize = 15) 
plt.ylabel("Frequência", fontsize = 15) 
plt.show()
# Out:
# Y: ['Bom', 'Ruim', 'Ótimo', 'Regular', 'Regular', 'Ótimo', 'Ótimo', 'Bom', 'Ótimo', 'Bom', 'Ótimo']
# Valores possíveis: ['Bom' 'Regular' 'Ruim' 'Ótimo']
# Frequência dos valores: [3. 2. 1. 5.]
